# %%
import pandas as pd

# %%
import random

# %%
cantidad= 10000

# %%
datos = {
    "nombre": ["Luisito Comunica", "Travel Vipes", "El mariana", "Rivers", "Lizbet", "Mr Beast"],
    "edad": [14,23,18,40,62,30],
    "plataforma": ["Youtube", "Tiktok", "Youtube", "Tiktok", "Tiktok", "Youtube"],
    "publicaciones_realizadas": [100,300,789,1000,368,1024],
    "numero_seguidores": [10000,100024, 1000,30000,1000,2000],
    "activo":[True,False,True,True,False, True],
    "fecha_creacion_canal": ["2026-01-10","2026-02-10","2026-02-10","2026-02-10","2026-04-10","2026-04-10"]
}

# %%
dfData = pd.DataFrame(datos)

# %%
dfData
# Out:
#              nombre  edad plataforma  publicaciones_realizadas  \
# 0  Luisito Comunica    14    Youtube                       100
# 1      Travel Vipes    23     Tiktok                       300
# 2        El mariana    18    Youtube                       789
# 3            Rivers    40     Tiktok                      1000
# 4            Lizbet    62     Tiktok                       368
# 5          Mr Beast    30    Youtube                      1024
#
#    numero_seguidores  activo fecha_creacion_canal
# 0              10000    True           2026-01-10
# 1             100024   False           2026-02-10
# 2               1000    True           2026-02-10
# 3              30000    True           2026-02-10
# 4               1000   False           2026-04-10
# 5               2000    True           2026-04-10

# %%
dfMillon = pd.DataFrame({
    "nombre": [random.choice(dfData["nombre"]) for _ in range(cantidad)],
    "edad": [random.randint(18,80) for _ in range(cantidad)],
    "plataforma": [random.choice(dfData["plataforma"]) for _ in range(cantidad)],
    "publicaciones_realizadas": [random.randint(1,1000) for _ in range(cantidad)],
    "numero_seguidores": [random.randint(1,1000000) for _ in range(cantidad)],
    "activo": [random.choice(dfData["activo"]) for _ in range(cantidad)],
    "fecha_creacion_canal": [random.choice(dfData["fecha_creacion_canal"]) for _ in range(cantidad)],
})

# %%
dfMillon.shape
# Out:
# (10000, 7)
